# %%
import os #allows us to access files/change filenames 
os.chdir('/Users/mirandamazzio/Desktop/TA/pmma_colloids')

# %%
print(os.getcwd())
# Out:
# /Users/mirandamazzio/Desktop/TA/pmma_colloids

# %%
import os
for filename in os.listdir("."):
    if filename.startswith("file"):
        os.rename(filename, filename[7:])
for f in os.listdir('/Users/mirandamazzio/Desktop/TA/pmma_colloids'):
    print (os.path.splitext(f))
# Out:
# ('z01', '.png')
# ('z02', '.png')
# ('z03', '.png')
# ('z04', '.png')
# ('z05', '.png')
# ('z06', '.png')
# ('z07', '.png')
# ('z08', '.png')
# ('z09', '.png')
# ('z10', '.png')
# ('z11', '.png')
# ('z12', '.png')
# ('z13', '.png')
# ('z14', '.png')
# ('z15', '.png')
# ('z16', '.png')
# ('z17', '.png')
# ('z18', '.png')
# ('z19', '.png')
# ('z20', '.png')
# ('z21', '.png')
# ('z22', '.png')
# ('z23', '.png')
# ('z24', '.png')
# ('z25', '.png')

# %%
def sorted_ls(path):
    mtime = lambda f: os.stat(os.path.join(path, f)).st_mtime
    return list(sorted(os.listdir(path), key=mtime))

# %%
sorted_ls('asm272_3d_5')
# Out:
# ['s_C001Z001T001.tif',
#  's_C001Z002T001.tif',
#  's_C001Z003T001.tif',
#  's_C001Z004T001.tif',
#  's_C001Z005T001.tif',
#  's_C001Z006T001.tif',
#  's_C001Z007T001.tif',
#  's_C001Z008T001.tif',
#  's_C001Z009T001.tif',
#  's_C001Z010T001.tif',
#  's_C001Z011T001.tif',
#  's_C001Z012T001.tif',
#  's_C001Z013T001.tif',
#  's_C001Z014T001.tif',
#  's_C001Z015T001.tif',
#  's_C001Z016T001.tif',
#  's_C001Z017T001.tif',
#  's_C001Z018T001.tif',
#  's_C001Z019T001.tif',
#  's_C001Z020T001.tif',
#  's_C001Z021T001.tif',
#  's_C001Z022T001.tif',
#  's_C001Z023T001.tif',
#  's_C001Z024T001.tif',
#  's_C001Z025T001.tif',
#  's_C001Z026T001.tif',
#  's_C001Z027T001.tif',
#  's_C001Z028T001.tif',
#  's_C001Z029T001.tif',
#  's_C001Z030T001.tif',
#  's_C001Z031T001.tif',
#  's_C001Z032T001.tif',
#  's_C001Z033T001.tif',
#  's_C001Z034T001.tif',
#  's_C001Z035T001.tif',
#  's_C001Z036T001.tif',
#  's_C001Z037T001.tif',
#  's_C001Z038T001.tif',
#  's_C001Z039T001.tif',
#  's_C001Z040T001.tif',
#  's_C001Z041T001.tif',
#  's_C001Z042T001.tif',
#  's_C001Z043T001.tif',
#  's_C001Z044T001.tif',
#  's_C001Z045T001.tif',
#  's_C001Z046T001.tif',
#  's_C001Z047T001.tif',
#  's_C001Z048T001.tif',
#  's_C001Z049T001.tif',
#  's_C001Z050T001.tif',
#  's_C001Z051T001.tif',
#  's_C001Z001T002.tif',
#  's_C001Z002T002.tif',
#  's_C001Z003T002.tif',
#  's_C001Z004T002.tif',
#  's_C001Z005T002.tif',
#  's_C001Z006T002.tif',
#  's_C001Z007T002.tif',
#  's_C001Z008T002.tif',
#  's_C001Z009T002.tif',
#  's_C001Z010T002.tif',
#  's_C001Z011T002.tif',
#  's_C001Z012T002.tif',
#  's_C001Z013T002.tif',
#  's_C001Z014T002.tif',
#  's_C001Z015T002.tif',
#  's_C001Z016T002.tif',
#  's_C001Z017T002.tif',
#  's_C001Z018T002.tif',
#  's_C001Z019T002.tif',
#  's_C001Z020T002.tif',
#  's_C001Z021T002.tif',
#  's_C001Z022T002.tif',
#  's_C001Z023T002.tif',
#  's_C001Z024T002.tif',
#  's_C001Z025T002.tif',
#  's_C001Z026T002.tif',
#  's_C001Z027T002.tif',
#  's_C001Z028T002.tif',
#  's_C001Z029T002.tif',
#  's_C001Z030T002.tif',
#  's_C001Z031T002.tif',
#  's_C001Z032T002.tif',
#  's_C001Z033T002.tif',
#  's_C001Z034T002.tif',
#  's_C001Z035T002.tif',
#  's_C001Z036T002.tif',
#  's_C001Z037T002.tif',
#  's_C001Z038T002.tif',
#  's_C001Z039T002.tif',
#  's_C001Z040T002.tif',
#  's_C001Z041T002.tif',
#  's_C001Z042T002.tif',
#  's_C001Z043T002.tif',
#  's_C001Z044T002.tif',
#  's_C001Z045T002.tif',
#  's_C001Z046T002.tif',
#  's_C001Z047T002.tif',
#  's_C001Z048T002.tif',
#  's_C001Z049T002.tif',
#  's_C001Z050T002.tif',
#  's_C001Z001T003.tif',
#  's_C001Z051T002.tif',
#  's_C001Z002T003.tif',
#  's_C001Z003T003.tif',
#  's_C001Z004T003.tif',
#  's_C001Z005T003.tif',
#  's_C001Z006T003.tif',
#  's_C001Z007T003.tif',
#  's_C001Z008T003.tif',
#  's_C001Z009T003.tif',
#  's_C001Z010T003.tif',
#  's_C001Z011T003.tif',
#  's_C001Z012T003.tif',
#  's_C001Z013T003.tif',
#  's_C001Z014T003.tif',
#  's_C001Z015T003.tif',
#  's_C001Z016T003.tif',
#  's_C001Z017T003.tif',
#  's_C001Z018T003.tif',
#  's_C001Z019T003.tif',
#  's_C001Z020T003.tif',
#  's_C001Z021T003.tif',
#  's_C001Z022T003.tif',
#  's_C001Z023T003.tif',
#  's_C001Z024T003.tif',
#  's_C001Z025T003.tif',
#  's_C001Z026T003.tif',
#  's_C001Z027T003.tif',
#  's_C001Z028T003.tif',
#  's_C001Z029T003.tif',
#  's_C001Z030T003.tif',
#  's_C001Z031T003.tif',
#  's_C001Z032T003.tif',
#  's_C001Z033T003.tif',
#  's_C001Z034T003.tif',
#  's_C001Z035T003.tif',
#  's_C001Z036T003.tif',
#  's_C001Z037T003.tif',
#  's_C001Z038T003.tif',
#  's_C001Z039T003.tif',
#  's_C001Z040T003.tif',
#  's_C001Z041T003.tif',
#  's_C001Z042T003.tif',
#  's_C001Z043T003.tif',
#  's_C001Z044T003.tif',
#  's_C001Z045T003.tif',
#  's_C001Z046T003.tif',
#  's_C001Z047T003.tif',
#  's_C001Z048T003.tif',
#  's_C001Z049T003.tif',
#  's_C001Z050T003.tif',
#  's_C001Z001T004.tif',
#  's_C001Z051T003.tif',
#  's_C001Z002T004.tif',
#  's_C001Z003T004.tif',
#  's_C001Z004T004.tif',
#  's_C001Z005T004.tif',
#  's_C001Z006T004.tif',
#  's_C001Z007T004.tif',
#  's_C001Z008T004.tif',
#  's_C001Z009T004.tif',
#  's_C001Z010T004.tif',
#  's_C001Z011T004.tif',
#  's_C001Z012T004.tif',
#  's_C001Z013T004.tif',
#  's_C001Z014T004.tif',
#  's_C001Z015T004.tif',
#  's_C001Z016T004.tif',
#  's_C001Z017T004.tif',
#  's_C001Z018T004.tif',
#  's_C001Z019T004.tif',
#  's_C001Z020T004.tif',
#  's_C001Z021T004.tif',
#  's_C001Z022T004.tif',
#  's_C001Z023T004.tif',
#  's_C001Z024T004.tif',
#  's_C001Z025T004.tif',
#  's_C001Z026T004.tif',
#  's_C001Z027T004.tif',
#  's_C001Z028T004.tif',
#  's_C001Z029T004.tif',
#  's_C001Z030T004.tif',
#  's_C001Z031T004.tif',
#  's_C001Z032T004.tif',
#  's_C001Z033T004.tif',
#  's_C001Z034T004.tif',
#  's_C001Z035T004.tif',
#  's_C001Z036T004.tif',
#  's_C001Z037T004.tif',
#  's_C001Z038T004.tif',
#  's_C001Z039T004.tif',
#  's_C001Z040T004.tif',
#  's_C001Z041T004.tif',
#  's_C001Z042T004.tif',
#  's_C001Z043T004.tif',
#  's_C001Z044T004.tif',
#  's_C001Z045T004.tif',
#  's_C001Z046T004.tif',
#  's_C001Z047T004.tif',
#  's_C001Z048T004.tif',
#  's_C001Z049T004.tif',
#  's_C001Z050T004.tif',
#  's_C001Z051T004.tif',
#  's_C001Z001T005.tif',
#  's_C001Z002T005.tif',
#  's_C001Z003T005.tif',
#  's_C001Z004T005.tif',
#  's_C001Z005T005.tif',
#  's_C001Z006T005.tif',
#  's_C001Z007T005.tif',
#  's_C001Z008T005.tif',
#  's_C001Z009T005.tif',
#  's_C001Z010T005.tif',
#  's_C001Z011T005.tif',
#  's_C001Z012T005.tif',
#  's_C001Z013T005.tif',
#  's_C001Z014T005.tif',
#  's_C001Z015T005.tif',
#  's_C001Z016T005.tif',
#  's_C001Z017T005.tif',
#  's_C001Z018T005.tif',
#  's_C001Z019T005.tif',
#  's_C001Z020T005.tif',
#  's_C001Z021T005.tif',
#  's_C001Z022T005.tif',
#  's_C001Z023T005.tif',
#  's_C001Z024T005.tif',
#  's_C001Z025T005.tif',
#  's_C001Z026T005.tif',
#  's_C001Z027T005.tif',
#  's_C001Z028T005.tif',
#  's_C001Z029T005.tif',
#  's_C001Z030T005.tif',
#  's_C001Z031T005.tif',
#  's_C001Z032T005.tif',
#  's_C001Z033T005.tif',
#  's_C001Z034T005.tif',
#  's_C001Z035T005.tif',
#  's_C001Z036T005.tif',
#  's_C001Z037T005.tif',
#  's_C001Z038T005.tif',
#  's_C001Z039T005.tif',
#  's_C001Z040T005.tif',
#  's_C001Z041T005.tif',
#  's_C001Z042T005.tif',
#  's_C001Z043T005.tif',
#  's_C001Z044T005.tif',
#  's_C001Z045T005.tif',
#  's_C001Z046T005.tif',
#  's_C001Z047T005.tif',
#  's_C001Z048T005.tif',
#  's_C001Z049T005.tif',
#  's_C001Z050T005.tif',
#  's_C001Z051T005.tif',
#  's_C001Z001T006.tif',
#  's_C001Z002T006.tif',
#  's_C001Z003T006.tif',
#  's_C001Z004T006.tif',
#  's_C001Z005T006.tif',
#  's_C001Z006T006.tif',
#  's_C001Z007T006.tif',
#  's_C001Z008T006.tif',
#  's_C001Z009T006.tif',
#  's_C001Z010T006.tif',
#  's_C001Z011T006.tif',
#  's_C001Z012T006.tif',
#  's_C001Z013T006.tif',
#  's_C001Z014T006.tif',
#  's_C001Z015T006.tif',
#  's_C001Z016T006.tif',
#  's_C001Z017T006.tif',
#  's_C001Z018T006.tif',
#  's_C001Z019T006.tif',
#  's_C001Z020T006.tif',
#  's_C001Z021T006.tif',
#  's_C001Z022T006.tif',
#  's_C001Z023T006.tif',
#  's_C001Z024T006.tif',
#  's_C001Z025T006.tif',
#  's_C001Z026T006.tif',
#  's_C001Z027T006.tif',
#  's_C001Z028T006.tif',
#  's_C001Z029T006.tif',
#  's_C001Z030T006.tif',
#  's_C001Z031T006.tif',
#  's_C001Z032T006.tif',
#  's_C001Z033T006.tif',
#  's_C001Z034T006.tif',
#  's_C001Z035T006.tif',
#  's_C001Z036T006.tif',
#  's_C001Z037T006.tif',
#  's_C001Z038T006.tif',
#  's_C001Z039T006.tif',
#  's_C001Z040T006.tif',
#  's_C001Z041T006.tif',
#  's_C001Z042T006.tif',
#  's_C001Z043T006.tif',
#  's_C001Z044T006.tif',
#  's_C001Z045T006.tif',
#  's_C001Z046T006.tif',
#  's_C001Z047T006.tif',
#  's_C001Z048T006.tif',
#  's_C001Z049T006.tif',
#  's_C001Z050T006.tif',
#  's_C001Z051T006.tif',
#  's_C001Z001T007.tif',
#  's_C001Z002T007.tif',
#  's_C001Z003T007.tif',
#  's_C001Z004T007.tif',
#  's_C001Z005T007.tif',
#  's_C001Z006T007.tif',
#  's_C001Z007T007.tif',
#  's_C001Z008T007.tif',
#  's_C001Z009T007.tif',
#  's_C001Z010T007.tif',
#  's_C001Z011T007.tif',
#  's_C001Z012T007.tif',
#  's_C001Z013T007.tif',
#  's_C001Z014T007.tif',
#  's_C001Z015T007.tif',
#  's_C001Z016T007.tif',
#  's_C001Z017T007.tif',
#  's_C001Z018T007.tif',
#  's_C001Z019T007.tif',
#  's_C001Z020T007.tif',
#  's_C001Z021T007.tif',
#  's_C001Z022T007.tif',
#  's_C001Z023T007.tif',
#  's_C001Z024T007.tif',
#  's_C001Z025T007.tif',
#  's_C001Z026T007.tif',
#  's_C001Z027T007.tif',
#  's_C001Z028T007.tif',
#  's_C001Z029T007.tif',
#  's_C001Z030T007.tif',
#  's_C001Z031T007.tif',
#  's_C001Z032T007.tif',
#  's_C001Z033T007.tif',
#  's_C001Z034T007.tif',
#  's_C001Z035T007.tif',
#  's_C001Z036T007.tif',
#  's_C001Z037T007.tif',
#  's_C001Z038T007.tif',
#  's_C001Z039T007.tif',
#  's_C001Z040T007.tif',
#  's_C001Z041T007.tif',
#  's_C001Z042T007.tif',
#  's_C001Z043T007.tif',
#  's_C001Z044T007.tif',
#  's_C001Z045T007.tif',
#  's_C001Z046T007.tif',
#  's_C001Z047T007.tif',
#  's_C001Z048T007.tif',
#  's_C001Z049T007.tif',
#  's_C001Z050T007.tif',
#  's_C001Z051T007.tif',
#  's_C001Z001T008.tif',
#  's_C001Z002T008.tif',
#  's_C001Z003T008.tif',
#  's_C001Z004T008.tif',
#  's_C001Z005T008.tif',
#  's_C001Z006T008.tif',
#  's_C001Z007T008.tif',
#  's_C001Z008T008.tif',
#  's_C001Z009T008.tif',
#  's_C001Z010T008.tif',
#  's_C001Z011T008.tif',
#  's_C001Z012T008.tif',
#  's_C001Z013T008.tif',
#  's_C001Z014T008.tif',
#  's_C001Z015T008.tif',
#  's_C001Z016T008.tif',
#  's_C001Z017T008.tif',
#  's_C001Z018T008.tif',
#  's_C001Z019T008.tif',
#  's_C001Z020T008.tif',
#  's_C001Z021T008.tif',
#  's_C001Z022T008.tif',
#  's_C001Z023T008.tif',
#  's_C001Z024T008.tif',
#  's_C001Z025T008.tif',
#  's_C001Z026T008.tif',
#  's_C001Z027T008.tif',
#  's_C001Z028T008.tif',
#  's_C001Z029T008.tif',
#  's_C001Z030T008.tif',
#  's_C001Z031T008.tif',
#  's_C001Z032T008.tif',
#  's_C001Z033T008.tif',
#  's_C001Z034T008.tif',
#  's_C001Z035T008.tif',
#  's_C001Z036T008.tif',
#  's_C001Z037T008.tif',
#  's_C001Z038T008.tif',
#  's_C001Z039T008.tif',
#  's_C001Z040T008.tif',
#  's_C001Z041T008.tif',
#  's_C001Z042T008.tif',
#  's_C001Z043T008.tif',
#  's_C001Z044T008.tif',
#  's_C001Z045T008.tif',
#  's_C001Z046T008.tif',
#  's_C001Z047T008.tif',
#  's_C001Z048T008.tif',
#  's_C001Z049T008.tif',
#  's_C001Z050T008.tif',
#  's_C001Z051T008.tif',
#  's_C001Z001T009.tif',
#  's_C001Z002T009.tif',
#  's_C001Z003T009.tif',
#  's_C001Z004T009.tif',
#  's_C001Z005T009.tif',
#  's_C001Z006T009.tif',
#  's_C001Z007T009.tif',
#  's_C001Z008T009.tif',
#  's_C001Z009T009.tif',
#  's_C001Z010T009.tif',
#  's_C001Z011T009.tif',
#  's_C001Z012T009.tif',
#  's_C001Z013T009.tif',
#  's_C001Z014T009.tif',
#  's_C001Z015T009.tif',
#  's_C001Z016T009.tif',
#  's_C001Z017T009.tif',
#  's_C001Z018T009.tif',
#  's_C001Z019T009.tif',
#  's_C001Z020T009.tif',
#  's_C001Z021T009.tif',
#  's_C001Z022T009.tif',
#  's_C001Z023T009.tif',
#  's_C001Z024T009.tif',
#  's_C001Z025T009.tif',
#  's_C001Z026T009.tif',
#  's_C001Z027T009.tif',
#  's_C001Z028T009.tif',
#  's_C001Z029T009.tif',
#  's_C001Z030T009.tif',
#  's_C001Z031T009.tif',
#  's_C001Z032T009.tif',
#  's_C001Z033T009.tif',
#  's_C001Z034T009.tif',
#  's_C001Z035T009.tif',
#  's_C001Z036T009.tif',
#  's_C001Z037T009.tif',
#  's_C001Z038T009.tif',
#  's_C001Z039T009.tif',
#  's_C001Z040T009.tif',
#  's_C001Z041T009.tif',
#  's_C001Z042T009.tif',
#  's_C001Z043T009.tif',
#  's_C001Z044T009.tif',
#  's_C001Z045T009.tif',
#  's_C001Z046T009.tif',
#  's_C001Z047T009.tif',
#  's_C001Z048T009.tif',
#  's_C001Z049T009.tif',
#  's_C001Z050T009.tif',
#  's_C001Z051T009.tif',
#  's_C001Z001T010.tif',
#  's_C001Z002T010.tif',
#  's_C001Z003T010.tif',
#  's_C001Z004T010.tif',
#  's_C001Z005T010.tif',
#  's_C001Z006T010.tif',
#  's_C001Z007T010.tif',
#  's_C001Z008T010.tif',
#  's_C001Z009T010.tif',
#  's_C001Z010T010.tif',
#  's_C001Z011T010.tif',
#  's_C001Z012T010.tif',
#  's_C001Z013T010.tif',
#  's_C001Z014T010.tif',
#  's_C001Z015T010.tif',
#  's_C001Z016T010.tif',
#  's_C001Z017T010.tif',
#  's_C001Z018T010.tif',
#  's_C001Z019T010.tif',
#  's_C001Z020T010.tif',
#  's_C001Z021T010.tif',
#  's_C001Z022T010.tif',
#  's_C001Z023T010.tif',
#  's_C001Z024T010.tif',
#  's_C001Z025T010.tif',
#  's_C001Z026T010.tif',
#  's_C001Z027T010.tif',
#  's_C001Z028T010.tif',
#  's_C001Z029T010.tif',
#  's_C001Z030T010.tif',
#  's_C001Z031T010.tif',
#  's_C001Z032T010.tif',
#  's_C001Z033T010.tif',
#  's_C001Z034T010.tif',
#  's_C001Z035T010.tif',
#  's_C001Z036T010.tif',
#  's_C001Z037T010.tif',
#  's_C001Z038T010.tif',
#  's_C001Z039T010.tif',
#  's_C001Z040T010.tif',
#  's_C001Z041T010.tif',
#  's_C001Z042T010.tif',
#  's_C001Z043T010.tif',
#  's_C001Z044T010.tif',
#  's_C001Z045T010.tif',
#  's_C001Z046T010.tif',
#  's_C001Z047T010.tif',
#  's_C001Z048T010.tif',
#  's_C001Z049T010.tif',
#  's_C001Z050T010.tif',
#  's_C001Z051T010.tif',
#  's_C001Z001T011.tif',
#  's_C001Z002T011.tif',
#  's_C001Z003T011.tif',
#  's_C001Z004T011.tif',
#  's_C001Z005T011.tif',
#  's_C001Z006T011.tif',
#  's_C001Z007T011.tif',
#  's_C001Z008T011.tif',
#  's_C001Z009T011.tif',
#  's_C001Z010T011.tif',
#  's_C001Z011T011.tif',
#  's_C001Z012T011.tif',
#  's_C001Z013T011.tif',
#  's_C001Z014T011.tif',
#  's_C001Z015T011.tif',
#  's_C001Z016T011.tif',
#  's_C001Z017T011.tif',
#  's_C001Z018T011.tif',
#  's_C001Z019T011.tif',
#  's_C001Z020T011.tif',
#  's_C001Z021T011.tif',
#  's_C001Z022T011.tif',
#  's_C001Z023T011.tif',
#  's_C001Z024T011.tif',
#  's_C001Z025T011.tif',
#  's_C001Z026T011.tif',
#  's_C001Z027T011.tif',
#  's_C001Z028T011.tif',
#  's_C001Z029T011.tif',
#  's_C001Z030T011.tif',
#  's_C001Z031T011.tif',
#  's_C001Z032T011.tif',
#  's_C001Z033T011.tif',
#  's_C001Z034T011.tif',
#  's_C001Z035T011.tif',
#  's_C001Z036T011.tif',
#  's_C001Z037T011.tif',
#  's_C001Z038T011.tif',
#  's_C001Z039T011.tif',
#  's_C001Z040T011.tif',
#  's_C001Z041T011.tif',
#  's_C001Z042T011.tif',
#  's_C001Z043T011.tif',
#  's_C001Z044T011.tif',
#  's_C001Z045T011.tif',
#  's_C001Z046T011.tif',
#  's_C001Z047T011.tif',
#  's_C001Z048T011.tif',
#  's_C001Z049T011.tif',
#  's_C001Z050T011.tif',
#  's_C001Z051T011.tif',
#  's_C001Z001T012.tif',
#  's_C001Z002T012.tif',
#  's_C001Z003T012.tif',
#  's_C001Z004T012.tif',
#  's_C001Z005T012.tif',
#  's_C001Z006T012.tif',
#  's_C001Z007T012.tif',
#  's_C001Z008T012.tif',
#  's_C001Z009T012.tif',
#  's_C001Z010T012.tif',
#  's_C001Z011T012.tif',
#  's_C001Z012T012.tif',
#  's_C001Z013T012.tif',
#  's_C001Z014T012.tif',
#  's_C001Z015T012.tif',
#  's_C001Z016T012.tif',
#  's_C001Z017T012.tif',
#  's_C001Z018T012.tif',
#  's_C001Z019T012.tif',
#  's_C001Z020T012.tif',
#  's_C001Z021T012.tif',
#  's_C001Z022T012.tif',
#  's_C001Z023T012.tif',
#  's_C001Z024T012.tif',
#  's_C001Z025T012.tif',
#  's_C001Z026T012.tif',
#  's_C001Z027T012.tif',
#  's_C001Z028T012.tif',
#  's_C001Z029T012.tif',
#  's_C001Z030T012.tif',
#  's_C001Z031T012.tif',
#  's_C001Z032T012.tif',
#  's_C001Z033T012.tif',
#  's_C001Z034T012.tif',
#  's_C001Z035T012.tif',
#  's_C001Z036T012.tif',
#  's_C001Z037T012.tif',
#  's_C001Z038T012.tif',
#  's_C001Z039T012.tif',
#  's_C001Z040T012.tif',
#  's_C001Z041T012.tif',
#  's_C001Z042T012.tif',
#  's_C001Z043T012.tif',
#  's_C001Z044T012.tif',
#  's_C001Z045T012.tif',
#  's_C001Z046T012.tif',
#  's_C001Z047T012.tif',
#  's_C001Z048T012.tif',
#  's_C001Z049T012.tif',
#  's_C001Z050T012.tif',
#  's_C001Z001T013.tif',
#  's_C001Z051T012.tif',
#  's_C001Z002T013.tif',
#  's_C001Z003T013.tif',
#  's_C001Z004T013.tif',
#  's_C001Z005T013.tif',
#  's_C001Z006T013.tif',
#  's_C001Z007T013.tif',
#  's_C001Z008T013.tif',
#  's_C001Z009T013.tif',
#  's_C001Z010T013.tif',
#  's_C001Z011T013.tif',
#  's_C001Z012T013.tif',
#  's_C001Z013T013.tif',
#  's_C001Z014T013.tif',
#  's_C001Z015T013.tif',
#  's_C001Z016T013.tif',
#  's_C001Z017T013.tif',
#  's_C001Z018T013.tif',
#  's_C001Z019T013.tif',
#  's_C001Z020T013.tif',
#  's_C001Z021T013.tif',
#  's_C001Z022T013.tif',
#  's_C001Z023T013.tif',
#  's_C001Z024T013.tif',
#  's_C001Z025T013.tif',
#  's_C001Z026T013.tif',
#  's_C001Z027T013.tif',
#  's_C001Z028T013.tif',
#  's_C001Z029T013.tif',
#  's_C001Z030T013.tif',
#  's_C001Z031T013.tif',
#  's_C001Z032T013.tif',
#  's_C001Z033T013.tif',
#  's_C001Z034T013.tif',
#  's_C001Z035T013.tif',
#  's_C001Z036T013.tif',
#  's_C001Z037T013.tif',
#  's_C001Z038T013.tif',
#  's_C001Z039T013.tif',
#  's_C001Z040T013.tif',
#  's_C001Z041T013.tif',
#  's_C001Z042T013.tif',
#  's_C001Z043T013.tif',
#  's_C001Z044T013.tif',
#  's_C001Z045T013.tif',
#  's_C001Z046T013.tif',
#  's_C001Z047T013.tif',
#  's_C001Z048T013.tif',
#  's_C001Z049T013.tif',
#  's_C001Z050T013.tif',
#  's_C001Z051T013.tif',
#  's_C001Z001T014.tif',
#  's_C001Z002T014.tif',
#  's_C001Z003T014.tif',
#  's_C001Z004T014.tif',
#  's_C001Z005T014.tif',
#  's_C001Z006T014.tif',
#  's_C001Z007T014.tif',
#  's_C001Z008T014.tif',
#  's_C001Z009T014.tif',
#  's_C001Z010T014.tif',
#  's_C001Z011T014.tif',
#  's_C001Z012T014.tif',
#  's_C001Z013T014.tif',
#  's_C001Z014T014.tif',
#  's_C001Z015T014.tif',
#  's_C001Z016T014.tif',
#  's_C001Z017T014.tif',
#  's_C001Z018T014.tif',
#  's_C001Z019T014.tif',
#  's_C001Z020T014.tif',
#  's_C001Z021T014.tif',
#  's_C001Z022T014.tif',
#  's_C001Z023T014.tif',
#  's_C001Z024T014.tif',
#  's_C001Z025T014.tif',
#  's_C001Z026T014.tif',
#  's_C001Z027T014.tif',
#  's_C001Z028T014.tif',
#  's_C001Z029T014.tif',
#  's_C001Z030T014.tif',
#  's_C001Z031T014.tif',
#  's_C001Z032T014.tif',
#  's_C001Z033T014.tif',
#  's_C001Z034T014.tif',
#  's_C001Z035T014.tif',
#  's_C001Z036T014.tif',
#  's_C001Z037T014.tif',
#  's_C001Z038T014.tif',
#  's_C001Z039T014.tif',
#  's_C001Z040T014.tif',
#  's_C001Z041T014.tif',
#  's_C001Z042T014.tif',
#  's_C001Z043T014.tif',
#  's_C001Z044T014.tif',
#  's_C001Z045T014.tif',
#  's_C001Z046T014.tif',
#  's_C001Z047T014.tif',
#  's_C001Z048T014.tif',
#  's_C001Z049T014.tif',
#  's_C001Z050T014.tif',
#  's_C001Z051T014.tif',
#  's_C001Z001T015.tif',
#  's_C001Z002T015.tif',
#  's_C001Z003T015.tif',
#  's_C001Z004T015.tif',
#  's_C001Z005T015.tif',
#  's_C001Z006T015.tif',
#  's_C001Z007T015.tif',
#  's_C001Z008T015.tif',
#  's_C001Z009T015.tif',
#  's_C001Z010T015.tif',
#  's_C001Z011T015.tif',
#  's_C001Z012T015.tif',
#  's_C001Z013T015.tif',
#  's_C001Z014T015.tif',
#  's_C001Z015T015.tif',
#  's_C001Z016T015.tif',
#  's_C001Z017T015.tif',
#  's_C001Z018T015.tif',
#  's_C001Z019T015.tif',
#  's_C001Z020T015.tif',
#  's_C001Z021T015.tif',
#  's_C001Z022T015.tif',
#  's_C001Z023T015.tif',
#  's_C001Z024T015.tif',
#  's_C001Z025T015.tif',
#  's_C001Z026T015.tif',
#  's_C001Z027T015.tif',
#  's_C001Z028T015.tif',
#  's_C001Z029T015.tif',
#  's_C001Z030T015.tif',
#  's_C001Z031T015.tif',
#  's_C001Z032T015.tif',
#  's_C001Z033T015.tif',
#  's_C001Z034T015.tif',
#  's_C001Z035T015.tif',
#  's_C001Z036T015.tif',
#  's_C001Z037T015.tif',
#  's_C001Z038T015.tif',
#  's_C001Z039T015.tif',
#  's_C001Z040T015.tif',
#  's_C001Z041T015.tif',
#  's_C001Z042T015.tif',
#  's_C001Z043T015.tif',
#  's_C001Z044T015.tif',
#  's_C001Z045T015.tif',
#  's_C001Z046T015.tif',
#  's_C001Z047T015.tif',
#  's_C001Z048T015.tif',
#  's_C001Z049T015.tif',
#  's_C001Z050T015.tif',
#  's_C001Z051T015.tif',
#  's_C001Z001T016.tif',
#  's_C001Z002T016.tif',
#  's_C001Z003T016.tif',
#  's_C001Z004T016.tif',
#  's_C001Z005T016.tif',
#  's_C001Z006T016.tif',
#  's_C001Z007T016.tif',
#  's_C001Z008T016.tif',
#  's_C001Z009T016.tif',
#  's_C001Z010T016.tif',
#  's_C001Z011T016.tif',
#  's_C001Z012T016.tif',
#  's_C001Z013T016.tif',
#  's_C001Z014T016.tif',
#  's_C001Z015T016.tif',
#  's_C001Z016T016.tif',
#  's_C001Z017T016.tif',
#  's_C001Z018T016.tif',
#  's_C001Z019T016.tif',
#  's_C001Z020T016.tif',
#  's_C001Z021T016.tif',
#  's_C001Z022T016.tif',
#  's_C001Z023T016.tif',
#  's_C001Z024T016.tif',
#  's_C001Z025T016.tif',
#  's_C001Z026T016.tif',
#  's_C001Z027T016.tif',
#  's_C001Z028T016.tif',
#  's_C001Z029T016.tif',
#  's_C001Z030T016.tif',
#  's_C001Z031T016.tif',
#  's_C001Z032T016.tif',
#  's_C001Z033T016.tif',
#  's_C001Z034T016.tif',
#  's_C001Z035T016.tif',
#  's_C001Z036T016.tif',
#  's_C001Z037T016.tif',
#  's_C001Z038T016.tif',
#  's_C001Z039T016.tif',
#  's_C001Z040T016.tif',
#  's_C001Z041T016.tif',
#  's_C001Z042T016.tif',
#  's_C001Z043T016.tif',
#  's_C001Z044T016.tif',
#  's_C001Z045T016.tif',
#  's_C001Z046T016.tif',
#  's_C001Z047T016.tif',
#  's_C001Z048T016.tif',
#  's_C001Z049T016.tif',
#  's_C001Z050T016.tif',
#  's_C001Z051T016.tif',
#  's_C001Z001T017.tif',
#  's_C001Z002T017.tif',
#  's_C001Z003T017.tif',
#  's_C001Z004T017.tif',
#  's_C001Z005T017.tif',
#  's_C001Z006T017.tif',
#  's_C001Z007T017.tif',
#  's_C001Z008T017.tif',
#  's_C001Z009T017.tif',
#  's_C001Z010T017.tif',
#  's_C001Z011T017.tif',
#  's_C001Z012T017.tif',
#  's_C001Z013T017.tif',
#  's_C001Z014T017.tif',
#  's_C001Z015T017.tif',
#  's_C001Z016T017.tif',
#  's_C001Z017T017.tif',
#  's_C001Z018T017.tif',
#  's_C001Z019T017.tif',
#  's_C001Z020T017.tif',
#  's_C001Z021T017.tif',
#  's_C001Z022T017.tif',
#  's_C001Z023T017.tif',
#  's_C001Z024T017.tif',
#  's_C001Z025T017.tif',
#  's_C001Z026T017.tif',
#  's_C001Z027T017.tif',
#  's_C001Z028T017.tif',
#  's_C001Z029T017.tif',
#  's_C001Z030T017.tif',
#  's_C001Z031T017.tif',
#  's_C001Z032T017.tif',
#  's_C001Z033T017.tif',
#  's_C001Z034T017.tif',
#  's_C001Z035T017.tif',
#  's_C001Z036T017.tif',
#  's_C001Z037T017.tif',
#  's_C001Z038T017.tif',
#  's_C001Z039T017.tif',
#  's_C001Z040T017.tif',
#  's_C001Z041T017.tif',
#  's_C001Z042T017.tif',
#  's_C001Z043T017.tif',
#  's_C001Z044T017.tif',
#  's_C001Z045T017.tif',
#  's_C001Z046T017.tif',
#  's_C001Z047T017.tif',
#  's_C001Z048T017.tif',
#  's_C001Z049T017.tif',
#  's_C001Z050T017.tif',
#  's_C001Z051T017.tif',
#  's_C001Z001T018.tif',
#  's_C001Z002T018.tif',
#  's_C001Z003T018.tif',
#  's_C001Z004T018.tif',
#  's_C001Z005T018.tif',
#  's_C001Z006T018.tif',
#  's_C001Z007T018.tif',
#  's_C001Z008T018.tif',
#  's_C001Z009T018.tif',
#  's_C001Z010T018.tif',
#  's_C001Z011T018.tif',
#  's_C001Z012T018.tif',
#  's_C001Z013T018.tif',
#  's_C001Z014T018.tif',
#  's_C001Z015T018.tif',
#  's_C001Z016T018.tif',
#  's_C001Z017T018.tif',
#  's_C001Z018T018.tif',
#  's_C001Z019T018.tif',
#  's_C001Z020T018.tif',
#  's_C001Z021T018.tif',
#  's_C001Z022T018.tif',
#  's_C001Z023T018.tif',
#  's_C001Z024T018.tif',
#  's_C001Z025T018.tif',
#  's_C001Z026T018.tif',
#  's_C001Z027T018.tif',
#  's_C001Z028T018.tif',
#  's_C001Z029T018.tif',
#  's_C001Z030T018.tif',
#  's_C001Z031T018.tif',
#  's_C001Z032T018.tif',
#  's_C001Z033T018.tif',
#  's_C001Z034T018.tif',
#  's_C001Z035T018.tif',
#  's_C001Z036T018.tif',
#  's_C001Z037T018.tif',
#  's_C001Z038T018.tif',
#  's_C001Z039T018.tif',
#  's_C001Z040T018.tif',
#  's_C001Z041T018.tif',
#  's_C001Z042T018.tif',
#  's_C001Z043T018.tif',
#  's_C001Z044T018.tif',
#  's_C001Z045T018.tif',
#  's_C001Z046T018.tif',
#  's_C001Z047T018.tif',
#  's_C001Z048T018.tif',
#  's_C001Z049T018.tif',
#  's_C001Z050T018.tif',
#  's_C001Z051T018.tif',
#  's_C001Z001T019.tif',
#  's_C001Z002T019.tif',
#  's_C001Z003T019.tif',
#  's_C001Z004T019.tif',
#  's_C001Z005T019.tif',
#  's_C001Z006T019.tif',
#  's_C001Z007T019.tif',
#  's_C001Z008T019.tif',
#  's_C001Z009T019.tif',
#  's_C001Z010T019.tif',
#  's_C001Z011T019.tif',
#  's_C001Z012T019.tif',
#  's_C001Z013T019.tif',
#  's_C001Z014T019.tif',
#  's_C001Z015T019.tif',
#  's_C001Z016T019.tif',
#  's_C001Z017T019.tif',
#  's_C001Z018T019.tif',
#  's_C001Z019T019.tif',
#  's_C001Z020T019.tif',
#  's_C001Z021T019.tif',
#  's_C001Z022T019.tif',
#  's_C001Z023T019.tif',
#  's_C001Z024T019.tif',
#  's_C001Z025T019.tif',
#  's_C001Z026T019.tif',
#  's_C001Z027T019.tif',
#  's_C001Z028T019.tif',
#  's_C001Z029T019.tif',
#  's_C001Z030T019.tif',
#  's_C001Z031T019.tif',
#  's_C001Z032T019.tif',
#  's_C001Z033T019.tif',
#  's_C001Z034T019.tif',
#  's_C001Z035T019.tif',
#  's_C001Z036T019.tif',
#  's_C001Z037T019.tif',
#  's_C001Z038T019.tif',
#  's_C001Z039T019.tif',
#  's_C001Z040T019.tif',
#  's_C001Z041T019.tif',
#  's_C001Z042T019.tif',
#  's_C001Z043T019.tif',
#  's_C001Z044T019.tif',
#  's_C001Z045T019.tif',
#  's_C001Z046T019.tif',
#  's_C001Z047T019.tif',
#  's_C001Z048T019.tif',
#  's_C001Z049T019.tif',
#  's_C001Z050T019.tif',
#  's_C001Z051T019.tif',
#  's_C001Z001T020.tif',
#  's_C001Z002T020.tif',
#  's_C001Z003T020.tif',
#  's_C001Z004T020.tif',
#  's_C001Z005T020.tif',
#  's_C001Z006T020.tif',
#  's_C001Z007T020.tif',
#  's_C001Z008T020.tif',
#  's_C001Z009T020.tif',
#  's_C001Z010T020.tif',
#  's_C001Z011T020.tif',
#  's_C001Z012T020.tif',
#  's_C001Z013T020.tif',
#  's_C001Z014T020.tif',
#  's_C001Z015T020.tif',
#  's_C001Z016T020.tif',
#  's_C001Z017T020.tif',
#  's_C001Z018T020.tif',
#  's_C001Z019T020.tif',
#  's_C001Z020T020.tif',
#  's_C001Z021T020.tif',
#  's_C001Z022T020.tif',
#  's_C001Z023T020.tif',
#  's_C001Z024T020.tif',
#  's_C001Z025T020.tif',
#  's_C001Z026T020.tif',
#  's_C001Z027T020.tif',
#  's_C001Z028T020.tif',
#  's_C001Z029T020.tif',
#  's_C001Z030T020.tif',
#  's_C001Z031T020.tif',
#  ...]

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-efb9a3aa0bee> in <module>()
#       1 import os #allows us to access files/change filenames
# ----> 2 os.chdir('/Users/mirandamazzio/Desktop/TA/asm272_3d_5 ')
#       3
#       4 def sorted_ls(path):
#       5     mtime = lambda f: os.stat(os.path.join(path, f)).st_mtime
#
# OSError: [Errno 2] No such file or directory: '/Users/mirandamazzio/Desktop/TA/asm272_3d_5 '
